# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv(Path('./csv_files/county_data_cleaned.csv'))
df.head()
# Out:
#       county state  percentage16_Donald_Trump  percentage16_Hillary_Clinton  \
# 0  Abbeville    SC                      0.629                         0.346
# 1     Acadia    LA                      0.773                         0.206
# 2   Accomack    VA                      0.545                         0.428
# 3        Ada    ID                      0.479                         0.387
# 4      Adair    IA                      0.653                         0.300
#
#    total_votes16  votes16_Donald_Trump  votes16_Hillary_Clinton  \
# 0        10724.0                6742.0                   3712.0
# 1        27386.0               21159.0                   5638.0
# 2        15755.0                8582.0                   6737.0
# 3       195587.0               93748.0                  75676.0
# 4         3759.0                2456.0                   1127.0
#
#    percentage20_Donald_Trump  percentage20_Joe_Biden  total_votes20  ...  \
# ...

# %%
plt.scatter(df.percentage16_Donald_Trump, df.Income)
plt.xlabel('2016 % of Votes for Donald')
plt.ylabel('Income')
plt.show()

# %%
plt.scatter(df.percentage20_Donald_Trump, df.Income)
plt.xlabel('2020 % Votes for Donald')
plt.ylabel('Income')
plt.show()

# %%
plt.scatter(df.percentage16_Hillary_Clinton, df.Income)
plt.xlabel('2016 % Votes for Hillary')
plt.ylabel('Income')
plt.show()

# %%
plt.scatter(df.percentage20_Joe_Biden, df.Income)
plt.xlabel('2020 % Votes for Joe')
plt.ylabel('Income')
plt.show()

# %%
X = df.percentage16_Donald_Trump.values.reshape(-1, 1)

# %%
y = df.Income

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (3046,)

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.show()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [-15335.13369877]
# 59335.45235801244

# %%
X = df.percentage20_Donald_Trump.values.reshape(-1, 1)

# %%
y = df.Income

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (3046,)

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.show()

# %%
X = df.percentage16_Hillary_Clinton.values.reshape(-1, 1)

# %%
y = df.Income

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (3046,)

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color='darkblue')
plt.show()

# %%
X = df.percentage20_Joe_Biden.values.reshape(-1, 1)

# %%
y = df.Income

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (3046,)

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color='darkblue')
plt.show()

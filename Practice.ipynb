# %%
import pandas as pd
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("csv_files\county_data_cleaned.csv")
df.head()
# Out:
#       county state  votes16_Donald_Trump  votes16_Hillary_Clinton  \
# 0  Abbeville    SC                6742.0                   3712.0
# 1     Acadia    LA               21159.0                   5638.0
# 2   Accomack    VA                8582.0                   6737.0
# 3        Ada    ID               93748.0                  75676.0
# 4      Adair    IA                2456.0                   1127.0
#
#    total_votes16  total_votes20  votes20_Donald_Trump  votes20_Joe_Biden  \
# 0        10724.0        12433.0                8215.0             4101.0
# 1        27386.0        28425.0               22596.0             5443.0
# 2        15755.0        16938.0                9172.0             7578.0
# 3       195587.0       259389.0              130699.0           120539.0
# 4         3759.0         4183.0                2917.0             1197.0
#
#      cases  deaths  ...  Hispanic  White  Black  Native  Asian  Pacific  \
# ...

# %%
covid_df = pd.read_csv("csv_files\Covid_data.csv")
covid_df.head()
# Out:
#       county state    cases  deaths  TotalPop
# 0  Abbeville    SC    805.0    17.0   24788.0
# 1     Acadia    LA   3182.0   102.0   62607.0
# 2   Accomack    VA   1227.0    19.0   32840.0
# 3        Ada    ID  17451.0   181.0  435117.0
# 4      Adair    IA    222.0     1.0    7192.0

# %%
columns = "cases deaths TotalPop".split()
columns
# Out:
# ['cases', 'deaths', 'TotalPop']

# %% [markdown]
#     ### Use label encoder for the unique counties and states

# %%
cs=df[["county","state"]]
cs.head()
# Out:
#       county state
# 0  Abbeville    SC
# 1     Acadia    LA
# 2   Accomack    VA
# 3        Ada    ID
# 4      Adair    IA

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
cs=cs.apply(le.fit_transform)
cs.head()
# Out:
#    county  state
# 0       0     39
# 1       1     17
# 2       2     44
# 3       3     12
# 4       4     11

# %%
# merge the encoded county/state df back into dataset
sub_df=df.drop(["county","state"],axis=1)
df=pd.concat([cs,sub_df],axis=1)
df.head()
# Out:
#    county  state  votes16_Donald_Trump  votes16_Hillary_Clinton  \
# 0       0     39                6742.0                   3712.0
# 1       1     17               21159.0                   5638.0
# 2       2     44                8582.0                   6737.0
# 3       3     12               93748.0                  75676.0
# 4       4     11                2456.0                   1127.0
#
#    total_votes16  total_votes20  votes20_Donald_Trump  votes20_Joe_Biden  \
# 0        10724.0        12433.0                8215.0             4101.0
# 1        27386.0        28425.0               22596.0             5443.0
# 2        15755.0        16938.0                9172.0             7578.0
# 3       195587.0       259389.0              130699.0           120539.0
# 4         3759.0         4183.0                2917.0             1197.0
#
#      cases  deaths  ...  Hispanic  White  Black  Native  Asian  Pacific  \
# ...

# %% [markdown]
# ### Counties Trump carried in 2016 and in 2020

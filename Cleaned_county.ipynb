# %%
# Initial imports
import pandas as pd

#  Import and read the county_data.csv.
county_df = pd.read_csv("csv_files/county_statistics.csv")
county_df.head()
# Out:
#    Numbers     county state  percentage16_Donald_Trump  \
# 0        0  Abbeville    SC                      0.629
# 1        1     Acadia    LA                      0.773
# 2        2   Accomack    VA                      0.545
# 3        3        Ada    ID                      0.479
# 4        4      Adair    IA                      0.653
#
#    percentage16_Hillary_Clinton  total_votes16  votes16_Donald_Trump  \
# 0                         0.346        10724.0                6742.0
# 1                         0.206        27386.0               21159.0
# 2                         0.428        15755.0                8582.0
# 3                         0.387       195587.0               93748.0
# 4                         0.300         3759.0                2456.0
#
#    votes16_Hillary_Clinton  percentage20_Donald_Trump  percentage20_Joe_Biden  \
# 0                   3712.0                      0.661                   0.330
# ...

# %%
county_df.dtypes
# Out:
# Numbers                           int64
# county                           object
# state                            object
# percentage16_Donald_Trump       float64
# percentage16_Hillary_Clinton    float64
# total_votes16                   float64
# votes16_Donald_Trump            float64
# votes16_Hillary_Clinton         float64
# percentage20_Donald_Trump       float64
# percentage20_Joe_Biden          float64
# total_votes20                   float64
# votes20_Donald_Trump            float64
# votes20_Joe_Biden               float64
# lat                             float64
# long                            float64
# cases                           float64
# deaths                          float64
# TotalPop                        float64
# Men                             float64
# Women                           float64
# Hispanic                        float64
# White                           float64
# Black                           float64
# ...

# %%
# Select the columns needed for our analysis
cleaned_county= county_df.loc[:,["county", "state", "votes16_Donald_Trump","votes16_Hillary_Clinton", 
                                 "total_votes16", "total_votes20", "votes20_Donald_Trump", "votes20_Joe_Biden",
                                "cases", "deaths","TotalPop","Men", "Women",  "Hispanic", "White",
                                 "Black","Native","Asian","Pacific", "Income", "IncomePerCap", "Poverty", "Unemployment" ]]

# %%
# Drop Null Values
cleaned_county= cleaned_county.dropna()

# %%
# Find Null Values
for column in cleaned_county.columns:
    print(f"Column{column}has {cleaned_county[column].isnull().sum()}null values")
# Out:
# Columncountyhas 0null values
# Columnstatehas 0null values
# Columnvotes16_Donald_Trumphas 0null values
# Columnvotes16_Hillary_Clintonhas 0null values
# Columntotal_votes16has 0null values
# Columntotal_votes20has 0null values
# Columnvotes20_Donald_Trumphas 0null values
# Columnvotes20_Joe_Bidenhas 0null values
# Columncaseshas 0null values
# Columndeathshas 0null values
# ColumnTotalPophas 0null values
# ColumnMenhas 0null values
# ColumnWomenhas 0null values
# ColumnHispanichas 0null values
# ColumnWhitehas 0null values
# ColumnBlackhas 0null values
# ColumnNativehas 0null values
# ColumnAsianhas 0null values
# ColumnPacifichas 0null values
# ColumnIncomehas 0null values
# ColumnIncomePerCaphas 0null values
# ColumnPovertyhas 0null values
# ColumnUnemploymenthas 0null values

# %%
# Find duplicate entries
print(f"Duplicate entries: {cleaned_county.duplicated().sum()}")
# Out:
# Duplicate entries: 0

# %%
cleaned_county.head()
# Out:
#       county state  votes16_Donald_Trump  votes16_Hillary_Clinton  \
# 0  Abbeville    SC                6742.0                   3712.0
# 1     Acadia    LA               21159.0                   5638.0
# 2   Accomack    VA                8582.0                   6737.0
# 3        Ada    ID               93748.0                  75676.0
# 4      Adair    IA                2456.0                   1127.0
#
#    total_votes16  total_votes20  votes20_Donald_Trump  votes20_Joe_Biden  \
# 0        10724.0        12433.0                8215.0             4101.0
# 1        27386.0        28425.0               22596.0             5443.0
# 2        15755.0        16938.0                9172.0             7578.0
# 3       195587.0       259389.0              130699.0           120539.0
# 4         3759.0         4183.0                2917.0             1197.0
#
#      cases  deaths  ...  Hispanic  White  Black  Native  Asian  Pacific  \
# ...

# %%
cleaned_county.dtypes
# Out:
# county                      object
# state                       object
# votes16_Donald_Trump       float64
# votes16_Hillary_Clinton    float64
# total_votes16              float64
# total_votes20              float64
# votes20_Donald_Trump       float64
# votes20_Joe_Biden          float64
# cases                      float64
# deaths                     float64
# TotalPop                   float64
# Men                        float64
# Women                      float64
# Hispanic                   float64
# White                      float64
# Black                      float64
# Native                     float64
# Asian                      float64
# Pacific                    float64
# Income                     float64
# IncomePerCap               float64
# Poverty                    float64
# Unemployment               float64
# dtype: object

# %%
# Saving cleaned data
file_path = "csv_files/county_data_cleaned.csv"
cleaned_county.to_csv(file_path, index=False)
